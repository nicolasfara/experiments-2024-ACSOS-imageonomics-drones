// %%
%use kandy

// %%
fun linearizationFunction(value: Double, min: Double, max: Double) = when {
    value >= max -> 1.0 // If  value is greater than MAX then fix it to 1.0
    else -> (value - min) / (max - min) // Change range into [0..1]
}

fun sigmoid(value: Double, m: Double, v: Double): Double {
    return (1 + ((value * (1 - m)) / (m * (1 - value))).pow(-v)).pow(-1)
}

val values = (20..80).toList()
val n5 = values.map { sigmoid(
    linearizationFunction(it.toDouble(), 20.0, 70.0),
    0.35,
    5.0
) }

val n10 = values.map { sigmoid(
    linearizationFunction(it.toDouble(), 20.0, 70.0),
    0.35,
    10.0
) }

val nBetter = values.map { sigmoid(
    linearizationFunction(it.toDouble(), 20.0, 70.0),
    0.40,
    4.0
) }

plot {
//    line {
//        x(values)
//        y(n5)
//        color = Color.PURPLE
//    }
//
//    line {
//        x(values)
//        y(n10)
//        color = Color.BLUE
//    }

    line {
        x(values)
        y(nBetter)
        color = Color.YELLOW
        width = 3.0
    }
    
    line {
        y(0..1)
        x.constant(40.0)
        type = LineType.DOTTED
        width = 2.0
    }
    
    layout { // Set plot layout
        title = "Simple plot with kandy-lets-plot" // Add title
        // Add caption
        caption = "See `examples` section for more\n complicated and interesting examples!"
        size = 2000 to 1500 // Plot dimension settings
    }
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='2000' height='1500' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.2.0/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;qke6O7&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//        var plotSpec={
// &quot;ggtitle&quot;:{
// &quot;text&quot;:&quot;Simple plot with kandy-lets-plot&quot;
// },
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// },
// &quot;ggsize&quot;:{
// &quot;width&quot;:2000.0,
// &quot;height&quot;:1500.0
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// ...
